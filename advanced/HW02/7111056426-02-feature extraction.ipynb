# %%
import numpy as np # array operations
import cv2 #opencv library read img operations
import os # use directory & join path
from pathlib import Path # 去掉副檔名
import pandas as pd # 匯出 csv

# data visualisation and manipulation
import matplotlib.pyplot as plt #show img and table

# %%
def get_mean_and_std(typeStr, img_name, x):
    x_mean, x_std = cv2.meanStdDev(x)
    x_mean = np.hstack(np.around(x_mean,2))
    x_std = np.hstack(np.around(x_std,2))
    
    # 印出平均與標準差
    if(typeStr == 's'):
        print("\n來源圖檔名: ", img_name)
    elif(typeStr == 't'):
        print("\n目標圖檔名: ", img_name)

    MeanStd = [x_mean,x_std]
    MeanStd_table = pd.DataFrame(MeanStd)
    col_name = ['red','green','blue']
    row_name = ['Mean','Standard Deviation']
    MeanStd_table.columns = col_name
    MeanStd_table.index = row_name
    print(MeanStd_table)

    # 匯出 answer table 成 csv 檔
    MeanStd_table.to_csv('feature/'+ img_name + '_dec.csv')
    
    return x_mean, x_std

# %%
if __name__ == '__main__':

    # weight_r, weight_g, weight_b = input("Enter 3 channel weight_red , weight_green, weight_blue(0.0 ≤ w ≤ 1.0):").split()
    
    # weight_r = float(weight_r)
    # weight_g = float(weight_g)
    # weight_b = float(weight_b)

    # 印出所有圖片
    DATASRC = 'source/'
    DATATRG = 'target/'

    # 抓目錄下所有圖檔檔名
    src_name = os.listdir(DATASRC)
    tar_name = os.listdir(DATATRG)

    for i in range (len(src_name)):
            
        # 圖片完整路徑
        src_path = DATASRC + src_name[i]
        tar_path = DATATRG + tar_name[i]
        
        # convert img to array 以彩色格式讀取(三維)
        src_bgr = cv2.imread(src_path ,cv2.IMREAD_COLOR)   
        tar_bgr = cv2.imread(tar_path ,cv2.IMREAD_COLOR)
        
        # 原為 BGR 轉為 RGB
        src_rgb = cv2.cvtColor(src_bgr,cv2.COLOR_BGR2RGB)
        tar_rgb = cv2.cvtColor(tar_bgr,cv2.COLOR_BGR2RGB)
        
        # 去掉副檔名
        src_name_temp= Path(src_path).stem 
        tar_name_temp= Path(tar_path).stem 
        # tar_name_tempp = tar_name_temp.lstrip('0'+str(i+1))
        # coltra_name = src_name_temp + tar_name_tempp
        
        # 做色彩轉換
        # coltra_rgb, s_mean, s_std, t_mean, t_std = color_transfer(src_rgb, tar_rgb, src_name_temp, tar_name_temp, coltra_name, i+1, weight_r, weight_g, weight_b)
        
        # 匯出平均及標準差成csv
        s_mean, s_std = get_mean_and_std('s', src_name_temp, src_rgb)
        t_mean, t_std = get_mean_and_std('t', tar_name_temp, tar_rgb)
# Out:
# 來源圖檔名:  01_kodim17
#                       red  green   blue
# Mean                82.68  77.05  69.02
# Standard Deviation  46.94  50.11  47.93
#
# 目標圖檔名:  01_kodim23
#                        red  green   blue
# Mean                121.66  109.6  75.79
# Standard Deviation   57.45   50.8  53.61
#
# 來源圖檔名:  02_kodim24
#                        red   green   blue
# Mean                113.47  109.55  94.27
# Standard Deviation   53.35   54.55  53.11
#
# 目標圖檔名:  02_kodim05
#                       red  green   blue
# Mean                91.50  81.02  67.52
# Standard Deviation  49.07  51.40  44.72
#
# 來源圖檔名:  03_kodim07
#                        red   green   blue
# Mean                117.56  110.72  85.37
# Standard Deviation   41.08   37.61  39.25
#
# 目標圖檔名:  03_kodim08
#                        red   green    blue
# Mean                127.96  121.08  116.00
# Standard Deviation   63.74   65.29   57.39
#
# 來源圖檔名:  04_miscanthus
#                        red   green    blue
# Mean                134.45  126.99  113.94
# Standard Deviation   80.69   77.25   73.34
#
# 目標圖檔名:  04_sunset
#                        red   green   blue
# Mean                125.30  106.91  86.04
# Standard Deviation   76.35   63.36  50.01
#
# 來源圖檔名:  05_bed
#                        red   green    blue
# Mean                139.29  135.44  110.14
# Standard Deviation   29.56   25.70   57.88
#
# 目標圖檔名:  05_blue
#                        red   green    blue
# Mean                108.12  104.75  121.49
# Standard Deviation   89.11   75.67   94.00
#
# 來源圖檔名:  06_horse
#                        red   green    blue
# Mean                172.59  167.07  139.13
# Standard Deviation   64.71   59.90   55.43
#
# 目標圖檔名:  06_hat
#                        red   green   blue
# Mean                133.84  102.21  87.21
# Standard Deviation   71.46   57.12  51.91
